# %%
var('n,k')
s1(k)=(-1)^(k+1)*1/k
s1.show()
# Out:
# k |--> (-1)^(k + 1)/k

# %%
s1.sum(k,1,oo)
# Out:
# log(2)

# %%
s2(k)=binomial(n,k)
s2.show()
# Out:
# k |--> binomial(n, k)

# %%
s2.sum(k,1,oo)
# Out:
# 2^n - 1

# %%
s2.sum(n,1,oo)
# Out:
# binomial(1, k)*hypergeometric((1, 2), (-k + 2,), 1)

# %%
q2(n)=s2.sum(k,1,oo)

# %%
q2(5000)
# Out:
# ...

# %%
n=ZZ(10)
type(n)
# Out:
# <type 'sage.rings.integer.Integer'>

# %%
help(ZZ)
# Out:
# Help on IntegerRing_class in module sage.categories.category object:
#
# class IntegerRing_class(sage.rings.ring.PrincipalIdealDomain)
#  |  IntegerRing_class()
#  |  File: sage/rings/integer_ring.pyx (starting at line 114)
#  |
#  |      The ring of integers.
#  |
#  |      In order to introduce the ring `\ZZ` of integers, we illustrate
#  |      creation, calling a few functions, and working with its elements.
#  |
#  |      ::
#  |
#  |          sage: Z = IntegerRing(); Z
#  |          Integer Ring
#  |          sage: Z.characteristic()
#  |          0
#  |          sage: Z.is_field()
#  |          False
#  |          sage: Z.category()
#  |          Join of Category of euclidean domains
#  |               and Category of infinite enumerated sets
#  |               and Category of metric spaces
#  |          sage: Z(2^(2^5) + 1)
#  |          4294967297
#  |
#  |      One can give strings to create integers. Strings starting with
# ...

# %%
l1=ZZ.range(1,40,2)
l1
# Out:
# <type 'list'>

# %%
type(l1)
# Out:
# <type 'list'>

# %%
ZZ.gcd(20,99) #Greatest common divisor
# Out:
# 1

# %%
ZZ.sum(l1)
# Out:
# 400

# %%
ZZ.prod(l1)
# Out:
# 319830986772877770815625

# %%
sum(l1)
# Out:
# 400

# %%
prod(l1)
# Out:
# 319830986772877770815625

# %%
n=ZZ(2)
n.powers(16)
# Out:
# [1, 2, 4, 8, 16, 32, 64, 128, 256, 512, 1024, 2048, 4096, 8192, 16384, 32768]

# %%
n=2
n.powers(16)
# Out:
# [1, 2, 4, 8, 16, 32, 64, 128, 256, 512, 1024, 2048, 4096, 8192, 16384, 32768]

# %%
515.next_prime()
# Out:
# 521

# %%
515.is_power_of(4)
# Out:
# False

# %%
515.is_perfect_power()
# Out:
# False

# %%
515.is_prime()
# Out:
# False

# %%
help(RR)
# Out:
# Help on RealField_class in module sage.categories.category object:
#
# class RealField_class(sage.rings.ring.Field)
#  |  RealField_class(int prec=53, int sci_not=0, long rnd=MPFR_RNDN)
#  |  File: sage/rings/real_mpfr.pyx (starting at line 437)
#  |
#  |      An approximation to the field of real numbers using floating point
#  |      numbers with any specified precision. Answers derived from
#  |      calculations in this approximation may differ from what they would
#  |      be if those calculations were performed in the true field of real
#  |      numbers. This is due to the rounding errors inherent to finite
#  |      precision calculations.
#  |
#  |      See the documentation for the module :mod:`sage.rings.real_mpfr` for more
#  |      details.
#  |
#  |  Method resolution order:
#  |      RealField_class
#  |      sage.rings.ring.Field
#  |      sage.rings.ring.PrincipalIdealDomain
#  |      sage.rings.ring.IntegralDomain
#  |      sage.rings.ring.CommutativeRing
# ...

# %%
RR.prec()
# Out:
# 53

# %%
RR.epsilon() #loss of precision as nummbers are not exact
# Out:
# 2.22044604925031e-16

# %%
QQ.epsilon() #no loss of precision as nummbers are exact
# Out:
# 0

# %%
R=RealField(512) #512 bits

# %%
R.prec()
# Out:
# 512

# %%
R.epsilon()
# Out:
# 1.49166814624004134865819306309258676747529430692008137885430366664125567701402366098723497808008556067230232065116722029068254561904506053209723296591842e-154

# %%
RR.pi
# Out:
# <built-in method pi of sage.rings.real_mpfr.RealField_class object at 0x7fe4cb3d1890>

# %%
pi.n()
# Out:
# 3.14159265358979

# %%
mypi=R.pi()
mypi
# Out:
# 3.14159265358979323846264338327950288419716939937510582097494459230781640628620899862803482534211706798214808651328230664709384460955058223172535940812848

# %%
ZZ.is_field()
# Out:
# False

# %%
QQ.is_field
# Out:
# <bound method RationalField_with_category.is_field of Rational Field>

# %%
RR.is_field
# Out:
# <built-in method is_field of sage.rings.real_mpfr.RealField_class object at 0x7fe4cb3d1890>

# %%
r1=24/7
r1.partial_fraction_decomposition()
# Out:
# (3, [3/7])

# %%
help(QQ)
# Out:
# Help on RationalField_with_category in module sage.rings.rational_field object:
#
# class RationalField_with_category(RationalField, sage.categories.category.JoinCategory.parent_class)
#  |  The class ``RationalField`` represents the field `\QQ` of rational numbers.
#  |
#  |  EXAMPLES::
#  |
#  |      sage: a = long(901824309821093821093812093810928309183091832091)
#  |      sage: b = QQ(a); b
#  |      901824309821093821093812093810928309183091832091
#  |      sage: QQ(b)
#  |      901824309821093821093812093810928309183091832091
#  |      sage: QQ(int(93820984323))
#  |      93820984323
#  |      sage: QQ(ZZ(901824309821093821093812093810928309183091832091))
#  |      901824309821093821093812093810928309183091832091
#  |      sage: QQ('-930482/9320842317')
#  |      -930482/9320842317
#  |      sage: QQ((-930482, 9320842317))
#  |      -930482/9320842317
#  |      sage: QQ([9320842317])
#  |      9320842317
#  |      sage: QQ(pari(39029384023840928309482842098430284398243982394))
# ...
