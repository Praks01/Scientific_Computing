# %%
pi.n(digits=20)
# Out:
# 3.1415926535897932385

# %%
plot(sin(x)*exp(-x),(x,0,2*pi), frame=True)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
DG=var('DG',latex_name='\\Delta G^\\alpha_0')
DG.show()
# Out:
# DG

# %%
exp1=integrate(3*tan(x)+sin(x)*x^2,x)
exp1.show()
# Out:
# -(x^2 - 2)*cos(x) + 2*x*sin(x) + 3*log(sec(x))

# %%
plot(erf(x),(x,0,5))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
[x1,x2, x3, x4, x5]=solve(x^5+1==0,x)
x1.show()
x2.show()
x3.show()
x4.show()
x5.show()
# Out:
# x == 1/4*(-1)^(1/5)*(sqrt(5) + I*sqrt(2*sqrt(5) + 10) - 1)
# x == -1/4*(-1)^(1/5)*(sqrt(5) - I*sqrt(-2*sqrt(5) + 10) + 1)
# x == -1/4*(-1)^(1/5)*(sqrt(5) + I*sqrt(-2*sqrt(5) + 10) + 1)
# x == 1/4*(-1)^(1/5)*(sqrt(5) - I*sqrt(2*sqrt(5) + 10) - 1)
# x == (-1)^(1/5)

# %%
import numpy as np

# %%
a=np.zeros((3,3),np.int32)
